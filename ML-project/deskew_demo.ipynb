# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import svm
from converters import convert_from_file
from deskew import deskew

# %%
X_train = convert_from_file('train-images.idx3-ubyte').reshape(60000,784)
y_train = convert_from_file('train-labels.idx1-ubyte')

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size = 0.3, random_state = 42)

# %%
from mpl_toolkits.axes_grid1 import AxesGrid
grid = AxesGrid(plt.figure(figsize=(8,15)), 141,  # similar to subplot(141)
                    nrows_ncols=(10, 2),
                    axes_pad=0.05
                    )
for idx, num in enumerate(range(0,10)):
    im = grid[2*idx].imshow(X_train[num].reshape(28,28))
    im2 = grid[2*idx+1].imshow(deskew(X_train[num].reshape(28,28)))

# %%
plt.subplot(1, 2, 1)
plt.imshow(X_train[10].reshape(28,28))

newim = deskew(X_train[10].reshape(28,28))
plt.subplot(1, 2, 2)
plt.imshow(newim)
